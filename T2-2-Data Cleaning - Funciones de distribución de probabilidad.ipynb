# %% [markdown]
# # Distribución Uniforme

# %% [markdown]
# f(x)= P(X=x) PDF = el conteo de la variable aleatoria ocurre para un valor concreto o rango, se llama función de distribución de probabilidad, ocurre con un valor concreto de la variable aleatoria.(Punto en la curva)
#
# En lugar de catalogar como se distribuyen los números con base en un valor, una variable aleatoria se puede definir por la función de distribución acumulada comulati density fintion (CDF)
#
# F(x)= P(X<=x) CDF = Probabilidad de que una variable aleatoria sea menor o igual que un valor concreto (área bajo la curva)

# %% [markdown]
# En una distribución uniforme hay que especificar el punto de origen y el punto final como parámetros de la función uniforme que se utilizan para generar el número aleatorio, todos los números son números equiprobables, no hay números más probables que otros

# %%
# Lammar librias necesarias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Desfinir limites de funcion de probabilidad uniforme
a = 1
b = 100
n = 1000000
data = np.random.uniform(a, b, n)

# %%
# %matplotlib inline
plt.hist(data)
# Out:
# (array([100265., 100527., 100087.,  99954., 100536.,  99237.,  99853.,
#          99898.,  99929.,  99714.]),
#  array([ 1.00000814, 10.90000471, 20.80000128, 30.69999786, 40.59999443,
#         50.499991  , 60.39998757, 70.29998414, 80.19998071, 90.09997728,
#         99.99997385]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #  Distribución Normal o Campana de Gauss

# %% [markdown]
# Una distribucion normal la definen la media y la distribucion tipica

# %%
data = np.random.randn(1000000)# randn es la función para números aleatorios para la función normal

# %%
x = range(1,1000001)
plt.plot(x, data)

# %%
# %matplotlib inline # estructura que se asemeja a una campana de Gauss
plt.hist(data)
# Out:
# (array([5.70000e+01, 1.42800e+03, 1.87000e+04, 1.10741e+05, 2.90169e+05,
#         3.44706e+05, 1.84390e+05, 4.46350e+04, 4.91800e+03, 2.56000e+02]),
#  array([-4.81754198, -3.89409127, -2.97064056, -2.04718984, -1.12373913,
#         -0.20028842,  0.72316229,  1.646613  ,  2.57006372,  3.49351443,
#          4.41696514]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x,sorted(data)) # Ordena los valores y representa la función de distribución acumulada, la función gausiana es esta pinta, al
# icio crece poco, luego crece de forma paulatina y luego crece muy poco, esta es una forma útil de poder contrastar que se trata de
# de una función gaussiana es ordenar los datos

# %% [markdown]
# Se ejecuto la funcion gauciana estandar con una media de cero y una desviacion tipica de 1

# %% [markdown]
# ### Función gausiana con una media que no es cero y una desviación típica diferente de 1

# %%
mu = 5.5 # Media
sd = 2.5 # Desviacion estandar
Z_10000 = np.random.randn(10000)
data = mu + sd * Z_10000 # Z = (X - mu) / sd -> N(0,1), X = mu + sd * Z
plt.hist(data)
# Out:
# (array([  33.,  153.,  660., 1572., 2545., 2609., 1572.,  686.,  149.,
#           21.]),
#  array([-3.18806185, -1.4497264 ,  0.28860905,  2.0269445 ,  3.76527995,
#          5.5036154 ,  7.24195085,  8.9802863 , 10.71862175, 12.4569572 ,
#         14.19529265]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# La función randn en lugar de recibir un único número entero especificando cuantas muestras aleatorias de normal 01 quieres tener, se le puede especificar un array de número o una colección de números para obtener diferentes array o diferentes versiones de la normal

# %%
data = np.random.randn(2,4) # pide dos colecciones de 4 elementos aleatorios cada uno
data # Dos muestras aleatorias, cada una de ellas de tamaño cuatro y cada una de ellas conforma una campana de gauss
# Out:
# array([[-1.0192551 ,  0.70139477, -0.76426253,  0.83831126],
#        [-1.19296854,  1.77062328,  0.44083709, -0.87377492]])

# %% [markdown]
# ### Inicio del Video 49

# %% [markdown]
# Utilizar distribuciones de probabilidad para estimar el valor de PI con la simulación de Montearlo

# %% [markdown]
# ## La simulación de Monte Carlo

# %% [markdown]
# Probabilidad de caer dentro del circulo es PI/4 = caer dentro del circulo/ caer dentro del cuadrado = area circulo / area cuadrado = PI x r x r / 2 x r x 2 x r =

# %% [markdown]
# * Generamos dos números aleatorios uniforme x e y entre 0 y 1 en total 1000 veces.
# * Calcularemos $z = x^2 + y^2$:
#     * Si $z < 1 \rightarrow$ estamos dentro del círculo. - el valor es menor que 1 estara dentro del circulo
#     * Si $z \geq 1 \rightarrow$ estamos fuera del círculo. - el valor es superior que 1 estara fuera del circulo
# * Calculamos el número total de veces que están dentro del círculo y lo dividimos entre el número total de intentos para obtener una aproximación de la probabilidad de caer dentro del círculo.
# * Usamos dicha probabilidad para aproximar el valor de π.
# * Repetimos el experimento un número suficiente de veces (por ejemplo 100), para obtener (100) diferentes aproximaciones de π.
# * Calculamos el promedio de los 100 experimentos anteriores para dar un valor final de π.

# %%
def pi_montecarlo(n, n_exp):
    pi_avg = 0
    pi_value_list = []
    for i in range(n_exp):
        value = 0
        x = np.random.uniform(0,1,n).tolist()
        y = np.random.uniform(0,1,n).tolist()
        for j in range(n):
            z = np.sqrt(x[j] * x[j] + y[j] * y[j])
            if z<=1:
                value += 1
        float_value = float(value)
        pi_value = float_value * 4 / n
        pi_value_list.append(pi_value)
        pi_avg += pi_value

    pi = pi_avg/n_exp

    print(pi)
    fig = plt.plot(pi_value_list)
    return (pi, fig)

# %%
pi_montecarlo(10000, 200)
# Out:
# 3.1415319999999993
# (3.1415319999999993, [<matplotlib.lines.Line2D at 0x14dc890e088>])

# %% [markdown]
# ### Dummy Data Sets

# %%
n = 1000000
data = pd.DataFrame(
    {
        'A' : np.random.randn(n),
        'B' : 1.5 + 2.5 * np.random.randn(n),
        'C' : np.random.uniform(5, 32, n)
    }
)

# %%
data.describe()
# Out:
#                     A               B               C
# count  1000000.000000  1000000.000000  1000000.000000
# mean        -0.000110        1.496113       18.501362
# std          0.998985        2.498226        7.797694
# min         -5.022362      -10.906216        5.000001
# 25%         -0.674266       -0.190519       11.749415
# 50%         -0.000941        1.493451       18.497466
# 75%          0.673907        3.183337       25.253346
# max          5.051391       13.890095       31.999986

# %%
plt.hist(data["A"])
# Out:
# (array([3.20000e+01, 1.24000e+03, 2.14030e+04, 1.37501e+05, 3.46118e+05,
#         3.40238e+05, 1.32363e+05, 1.99360e+04, 1.14100e+03, 2.80000e+01]),
#  array([-5.02236185, -4.01498655, -3.00761125, -2.00023595, -0.99286064,
#          0.01451466,  1.02188996,  2.02926526,  3.03664056,  4.04401586,
#          5.05139117]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["B"])
# Out:
# (array([3.40000e+01, 1.40700e+03, 2.19290e+04, 1.36796e+05, 3.39589e+05,
#         3.39131e+05, 1.37528e+05, 2.20620e+04, 1.49300e+03, 3.10000e+01]),
#  array([-10.90621592,  -8.42658483,  -5.94695374,  -3.46732266,
#          -0.98769157,   1.49193952,   3.97157061,   6.45120169,
#           8.93083278,  11.41046387,  13.89009496]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["C"])
# Out:
# (array([ 99926., 100455.,  99407., 100404.,  99909.,  99727.,  99995.,
#          99847., 100019., 100311.]),
#  array([ 5.000001  ,  7.69999955, 10.39999809, 13.09999663, 15.79999517,
#         18.49999372, 21.19999226, 23.8999908 , 26.59998934, 29.29998789,
#         31.99998643]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["C"])
# Out:
# (array([ 99926., 100455.,  99407., 100404.,  99909.,  99727.,  99995.,
#          99847., 100019., 100311.]),
#  array([ 5.000001  ,  7.69999955, 10.39999809, 13.09999663, 15.79999517,
#         18.49999372, 21.19999226, 23.8999908 , 26.59998934, 29.29998789,
#         31.99998643]),
#  <BarContainer object of 10 artists>)

# %%
data = pd.read_csv("python-ml-course-master/datasets/customer-churn-model/Customer Churn Model.txt")

# %%
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
colum_names = data.columns.values.tolist()

# %%
a = len(colum_names)
a
# Out:
# 21

# %%
new_data = pd.DataFrame(
    {
        'Column Name': colum_names,
        'A' : np.random.randn(a),
        'B' : np.random.uniform(0,1,a)
    }, index = range(42, 42 + a)
)

# %%
new_data
# Out:
#        Column Name         A         B
# 42           State  1.016693  0.929488
# 43  Account Length  1.043498  0.067115
# 44       Area Code -0.302376  0.310713
# 45           Phone  1.491953  0.925720
# 46      Int'l Plan -0.079971  0.419236
# 47      VMail Plan -0.533977  0.920001
# 48   VMail Message  0.310645  0.547695
# 49        Day Mins -0.335092  0.314561
# 50       Day Calls -0.418855  0.111630
# 51      Day Charge  0.704534  0.607075
# 52        Eve Mins  0.715210  0.461796
# 53       Eve Calls -1.378327  0.641661
# 54      Eve Charge  0.558140  0.566983
# 55      Night Mins -0.481543  0.129511
# 56     Night Calls -1.204711  0.238026
# 57    Night Charge  0.556190  0.426110
# 58       Intl Mins  0.840882  0.539704
# 59      Intl Calls  1.863334  0.594624
# 60     Intl Charge  0.150604  0.720061
# 61  CustServ Calls -1.150833  0.049600
# 62          Churn?  0.442041  0.664788
